# %%
import os
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
django.setup()

# %%
from rest_framework import serializers
from profiles.models import Profiles # اگه اسم اپت چیز دیگه‌ایه جایگزین کن

class ProfileSerializer(serializers.ModelSerializer):
    class Meta:
        model = Profiles
        fields = ['phone_number', 'first_name', 'last_name']

# %%
import asyncio
from asgiref.sync import sync_to_async

data = {
    "phone_number": "09123456789",
    "first_name": "Ali",
    "last_name": "Rezaei"
}

serializer = ProfileSerializer(data=data)

async def save_profile():
    if serializer.is_valid():
        profile = await sync_to_async(serializer.save)()
        print("Saved:", profile)
    else:
        print("Errors:", serializer.errors)

await save_profile()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:279, in BaseDatabaseWrapper.ensure_connection(self)
#     278 with self.wrap_database_errors:
# --> 279     self.connect()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:256, in BaseDatabaseWrapper.connect(self)
#     255 conn_params = self.get_connection_params()
# --> 256 self.connection = self.get_new_connection(conn_params)
#     257 self.set_autocommit(self.settings_dict["AUTOCOMMIT"])
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\mysql\base.py:256, in DatabaseWrapper.get_new_connection(self, conn_params)
#     254 @async_unsafe
#     255 def get_new_connection(self, conn_params):
# --> 256     connection = Database.connect(**conn_params)
#     257     # bytes encoder in mysqlclient doesn't work and was added only to
#     258     # prevent KeyErrors in Django < 2.0. We can remove this workaround when
#     259     # mysqlclient 2.1 becomes the minimal mysqlclient supported by Django.
#     260     # See https://github.com/PyMySQL/mysqlclient/issues/489
#
# File d:\anacoda\envs\myenv\Lib\site-packages\MySQLdb\__init__.py:121, in Connect(*args, **kwargs)
#     119 from MySQLdb.connections import Connection
# --> 121 return Connection(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\MySQLdb\connections.py:200, in Connection.__init__(self, *args, **kwargs)
#     199 self._set_attributes(*args, **kwargs2)
# --> 200 super().__init__(*args, **kwargs2)
#     202 self.cursorclass = cursorclass
#
# OperationalError: (1045, "Plugin caching_sha2_password could not be loaded: The specified module could not be found. Library path is 'caching_sha2_password.dll'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 19
#      16     else:
#      17         print("Errors:", serializer.errors)
# ---> 19 await save_profile()
#
# Cell In[4], line 14, in save_profile()
#      12 async def save_profile():
#      13     if serializer.is_valid():
# ---> 14         profile = await sync_to_async(serializer.save)()
#      15         print("Saved:", profile)
#      16     else:
#
# File d:\anacoda\envs\myenv\Lib\site-packages\asgiref\sync.py:468, in SyncToAsync.__call__(self, *args, **kwargs)
#     466 ret: _R
#     467 try:
# --> 468     ret = await asyncio.shield(exec_coro)
#     469 except asyncio.CancelledError:
#     470     cancel_parent = True
#
# File d:\anacoda\envs\myenv\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\asgiref\sync.py:522, in SyncToAsync.thread_handler(self, loop, exc_info, task_context, func, *args, **kwargs)
#     520         return func(*args, **kwargs)
#     521 else:
# --> 522     return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\rest_framework\serializers.py:210, in BaseSerializer.save(self, **kwargs)
#     206     assert self.instance is not None, (
#     207         '`update()` did not return an object instance.'
#     208     )
#     209 else:
# --> 210     self.instance = self.create(validated_data)
#     211     assert self.instance is not None, (
#     212         '`create()` did not return an object instance.'
#     213     )
#     215 return self.instance
#
# File d:\anacoda\envs\myenv\Lib\site-packages\rest_framework\serializers.py:991, in ModelSerializer.create(self, validated_data)
#     988         many_to_many[field_name] = validated_data.pop(field_name)
#     990 try:
# --> 991     instance = ModelClass._default_manager.create(**validated_data)
#     992 except TypeError:
#     993     tb = traceback.format_exc()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\query.py:663, in QuerySet.create(self, **kwargs)
#     661 obj = self.model(**kwargs)
#     662 self._for_write = True
# --> 663 obj.save(force_insert=True, using=self.db)
#     664 return obj
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\base.py:902, in Model.save(self, force_insert, force_update, using, update_fields, *args)
#     899     if loaded_fields:
#     900         update_fields = frozenset(loaded_fields)
# --> 902 self.save_base(
#     903     using=using,
#     904     force_insert=force_insert,
#     905     force_update=force_update,
#     906     update_fields=update_fields,
#     907 )
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\base.py:1008, in Model.save_base(self, raw, force_insert, force_update, using, update_fields)
#    1004         force_insert = self._validate_force_insert(force_insert)
#    1005         parent_inserted = self._save_parents(
#    1006             cls, using, update_fields, force_insert
#    1007         )
# -> 1008     updated = self._save_table(
#    1009         raw,
#    1010         cls,
#    1011         force_insert or parent_inserted,
#    1012         force_update,
#    1013         using,
#    1014         update_fields,
#    1015     )
#    1016 # Store the database on which the object was saved
#    1017 self._state.db = using
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\base.py:1169, in Model._save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#    1163 fields = [
#    1164     f
#    1165     for f in meta.local_concrete_fields
#    1166     if not f.generated and (pk_set or f is not meta.auto_field)
#    1167 ]
#    1168 returning_fields = meta.db_returning_fields
# -> 1169 results = self._do_insert(
#    1170     cls._base_manager, using, fields, returning_fields, raw
#    1171 )
#    1172 if results:
#    1173     for value, field in zip(results[0], returning_fields):
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\base.py:1210, in Model._do_insert(self, manager, using, fields, returning_fields, raw)
#    1205 def _do_insert(self, manager, using, fields, returning_fields, raw):
#    1206     """
#    1207     Do an INSERT. If returning_fields is defined then this method should
#    1208     return the newly created data for the model.
#    1209     """
# -> 1210     return manager._insert(
#    1211         [self],
#    1212         fields=fields,
#    1213         returning_fields=returning_fields,
#    1214         using=using,
#    1215         raw=raw,
#    1216     )
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\query.py:1854, in QuerySet._insert(self, objs, fields, returning_fields, raw, using, on_conflict, update_fields, unique_fields)
#    1847 query = sql.InsertQuery(
#    1848     self.model,
#    1849     on_conflict=on_conflict,
#    1850     update_fields=update_fields,
#    1851     unique_fields=unique_fields,
#    1852 )
#    1853 query.insert_values(fields, objs, raw=raw)
# -> 1854 return query.get_compiler(using=using).execute_sql(returning_fields)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\sql\compiler.py:1879, in SQLInsertCompiler.execute_sql(self, returning_fields)
#    1877 self.returning_fields = returning_fields
#    1878 cols = []
# -> 1879 with self.connection.cursor() as cursor:
#    1880     for sql, params in self.as_sql():
#    1881         cursor.execute(sql, params)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:320, in BaseDatabaseWrapper.cursor(self)
#     317 @async_unsafe
#     318 def cursor(self):
#     319     """Create a cursor, opening a connection if necessary."""
# --> 320     return self._cursor()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:296, in BaseDatabaseWrapper._cursor(self, name)
#     294 def _cursor(self, name=None):
#     295     self.close_if_health_check_failed()
# --> 296     self.ensure_connection()
#     297     with self.wrap_database_errors:
#     298         return self._prepare_cursor(self.create_cursor(name))
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:278, in BaseDatabaseWrapper.ensure_connection(self)
#     274 if self.in_atomic_block and self.closed_in_transaction:
#     275     raise ProgrammingError(
#     276         "Cannot open a new connection in an atomic block."
#     277     )
# --> 278 with self.wrap_database_errors:
#     279     self.connect()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\utils.py:91, in DatabaseErrorWrapper.__exit__(self, exc_type, exc_value, traceback)
#      89 if dj_exc_type not in (DataError, IntegrityError):
#      90     self.wrapper.errors_occurred = True
# ---> 91 raise dj_exc_value.with_traceback(traceback) from exc_value
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:279, in BaseDatabaseWrapper.ensure_connection(self)
#     275     raise ProgrammingError(
#     276         "Cannot open a new connection in an atomic block."
#     277     )
#     278 with self.wrap_database_errors:
# --> 279     self.connect()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\base\base.py:256, in BaseDatabaseWrapper.connect(self)
#     254 # Establish the connection
#     255 conn_params = self.get_connection_params()
# --> 256 self.connection = self.get_new_connection(conn_params)
#     257 self.set_autocommit(self.settings_dict["AUTOCOMMIT"])
#     258 self.init_connection_state()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\backends\mysql\base.py:256, in DatabaseWrapper.get_new_connection(self, conn_params)
#     254 @async_unsafe
#     255 def get_new_connection(self, conn_params):
# --> 256     connection = Database.connect(**conn_params)
#     257     # bytes encoder in mysqlclient doesn't work and was added only to
#     258     # prevent KeyErrors in Django < 2.0. We can remove this workaround when
#     259     # mysqlclient 2.1 becomes the minimal mysqlclient supported by Django.
#     260     # See https://github.com/PyMySQL/mysqlclient/issues/489
#     261     if connection.encoders.get(bytes) is bytes:
#
# File d:\anacoda\envs\myenv\Lib\site-packages\MySQLdb\__init__.py:121, in Connect(*args, **kwargs)
#     118 """Factory function for connections.Connection."""
#     119 from MySQLdb.connections import Connection
# --> 121 return Connection(*args, **kwargs)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\MySQLdb\connections.py:200, in Connection.__init__(self, *args, **kwargs)
#     197 autocommit = kwargs2.pop("autocommit", False)
#     199 self._set_attributes(*args, **kwargs2)
# --> 200 super().__init__(*args, **kwargs2)
#     202 self.cursorclass = cursorclass
#     203 self.encoders = {
#     204     k: v
#     205     for k, v in conv.items()
#     206     if type(k) is not int  # noqa: E721
#     207 }
#
# OperationalError: (1045, "Plugin caching_sha2_password could not be loaded: The specified module could not be found. Library path is 'caching_sha2_password.dll'")

# %%
from profiles.models import Profiles
from profiles.serializers import ProfileSerializer
profiles=Profiles.objects.all()
serializer=ProfileSerializer(profiles , many=True)
serializer.data
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[4], line 5
#       3 profiles=Profiles.objects.all()
#       4 serializer=ProfileSerializer(profiles , many=True)
# ----> 5 serializer.data
#
# File d:\anacoda\envs\myenv\Lib\site-packages\rest_framework\serializers.py:797, in ListSerializer.data(self)
#     795 @property
#     796 def data(self):
# --> 797     ret = super().data
#     798     return ReturnList(ret, serializer=self)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\rest_framework\serializers.py:251, in BaseSerializer.data(self)
#     249 if not hasattr(self, '_data'):
#     250     if self.instance is not None and not getattr(self, '_errors', None):
# --> 251         self._data = self.to_representation(self.instance)
#     252     elif hasattr(self, '_validated_data') and not getattr(self, '_errors', None):
#     253         self._data = self.to_representation(self.validated_data)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\rest_framework\serializers.py:716, in ListSerializer.to_representation(self, data)
#     711 # Dealing with nested relationships, data can be a Manager,
#     712 # so, first get a queryset from the Manager if needed
#     713 iterable = data.all() if isinstance(data, models.manager.BaseManager) else data
#     715 return [
# --> 716     self.child.to_representation(item) for item in iterable
#     717 ]
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\query.py:384, in QuerySet.__iter__(self)
#     369 def __iter__(self):
#     370     """
#     371     The queryset iterator protocol uses three nested iterators in the
#     372     default case:
#    (...)    382            - Responsible for turning the rows into model objects.
#     383     """
# --> 384     self._fetch_all()
#     385     return iter(self._result_cache)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\query.py:1935, in QuerySet._fetch_all(self)
#    1933 def _fetch_all(self):
#    1934     if self._result_cache is None:
# -> 1935         self._result_cache = list(self._iterable_class(self))
#    1936     if self._prefetch_related_lookups and not self._prefetch_done:
#    1937         self._prefetch_related_objects()
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\query.py:91, in ModelIterable.__iter__(self)
#      88 compiler = queryset.query.get_compiler(using=db)
#      89 # Execute the query. This will also fill compiler.select, klass_info,
#      90 # and annotations.
# ---> 91 results = compiler.execute_sql(
#      92     chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size
#      93 )
#      94 select, klass_info, annotation_col_map = (
#      95     compiler.select,
#      96     compiler.klass_info,
#      97     compiler.annotation_col_map,
#      98 )
#      99 model_cls = klass_info["model"]
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\db\models\sql\compiler.py:1620, in SQLCompiler.execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1618     cursor = self.connection.chunked_cursor()
#    1619 else:
# -> 1620     cursor = self.connection.cursor()
#    1621 try:
#    1622     cursor.execute(sql, params)
#
# File d:\anacoda\envs\myenv\Lib\site-packages\django\utils\asyncio.py:24, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      22 else:
#      23     if not os.environ.get("DJANGO_ALLOW_ASYNC_UNSAFE"):
# ---> 24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
#      26 return func(*args, **kwargs)
#
# SynchronousOnlyOperation: You cannot call this from an async context - use a thread or sync_to_async.
